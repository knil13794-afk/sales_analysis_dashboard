# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Kalyani\DataAnalyst\SixMonths\Day 9 Python_Data_Analysis\sales_data.csv")

# %%
df.head()
# Out:
#    order_id  order_date customer_name  region product     category  \
# 0         1  01-01-2024          Amit    Pune  Laptop  Electronics
# 1         2  02-01-2024          Neha  Mumbai  Mobile  Electronics
# 2         3  03-01-2024           Raj   Delhi  Tablet  Electronics
# 3         4  04-01-2024         Priya    Pune   Chair    Furniture
# 4         5  05-01-2024         Karan  Mumbai    Desk    Furniture
#
#    sales_amount  quantity
# 0         50000         1
# 1         20000         2
# 2         15000         1
# 3          7000         3
# 4         12000         1

# %%
print(df['sales_amount'].sum())
# Out:
# 261000

# %%
print(df['sales_amount'].mean())
# Out:
# 26100.0

# %%
print(df['sales_amount'].max())
# Out:
# 60000

# %%
df[df['region']=='Pune']
# Out:
#    order_id  order_date customer_name region product     category  \
# 0         1  01-01-2024          Amit   Pune  Laptop  Electronics
# 3         4  04-01-2024         Priya   Pune   Chair    Furniture
# 6         7  07-01-2024          Amit   Pune  Mobile  Electronics
# 9        10  10-01-2024         Priya   Pune  Laptop  Electronics
#
#    sales_amount  quantity
# 0         50000         1
# 3          7000         3
# 6         18000         1
# 9         60000         1

# %%
df.groupby('region')['sales_amount'].sum()
# Out:
# region
# Delhi      85000
# Mumbai     41000
# Pune      135000
# Name: sales_amount, dtype: int64

# %%
df.isnull().sum()
# Out:
# order_id         0
# order_date       0
# customer_name    0
# region           0
# product          0
# category         0
# sales_amount     0
# quantity         0
# dtype: int64

# %%
df.dropna()
# Out:
#    order_id  order_date customer_name  region product     category  \
# 0         1  01-01-2024          Amit    Pune  Laptop  Electronics
# 1         2  02-01-2024          Neha  Mumbai  Mobile  Electronics
# 2         3  03-01-2024           Raj   Delhi  Tablet  Electronics
# 3         4  04-01-2024         Priya    Pune   Chair    Furniture
# 4         5  05-01-2024         Karan  Mumbai    Desk    Furniture
# 5         6  06-01-2024         Sneha   Delhi  Laptop  Electronics
# 6         7  07-01-2024          Amit    Pune  Mobile  Electronics
# 7         8  08-01-2024          Neha  Mumbai   Chair    Furniture
# 8         9  09-01-2024           Raj   Delhi    Desk    Furniture
# 9        10  10-01-2024         Priya    Pune  Laptop  Electronics
#
#    sales_amount  quantity
# 0         50000         1
# 1         20000         2
# 2         15000         1
# 3          7000         3
# 4         12000         1
# 5         55000         1
# 6         18000         1
# ...

# %%
df.to_csv("Cleaned_Sales.csv", index=False)
